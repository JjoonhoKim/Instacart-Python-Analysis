# %% [markdown]
# # Importing Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Merged Dataframe

# %%
path = r'C:\Users\Akira\Documents\Instacart Basket Analysis'

# %%
df_ords_prods_merged = pd.read_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %% [markdown]
# ## If Statements - introducing new conditions to specific elements

# %% [markdown]
# user-defined functions is your own functions to write in order to solve specific problems, it's more open ended and to your own use
#
# The basic structure of a user-defined function is as follows:
#
# 1)A definition of the name and arguments the function will take
#
# 2)What the function is meant to do

# %%
# example of a function to sum values

def add_num (x,y):
    sum = x + y
    return sum

# %% [markdown]
# The function starts with a definition, def. In the definition, the function is given a descriptive name: add_num(). Also, two arguments, x and y, are designated, which tells Python to always expect two arguments when this function is called.
#
# After the definition, you’ll tell the function what to do in the body. Here, the two arguments, x and y, are added and assigned to a new variable, sum. Finally, sum is returned (the value of sum is printed). What this function will do, then, is add the two numbers you give it and return the sum.

# %%
# running function
add_num(9,11)
# Out:
# 20

# %% [markdown]
# ## We will be manipulating the merged dataframe and apply the following criteria
#
# You’ll apply the following criteria:
#
# 1)If the item’s price is lower than or equal to $5, it will be labeled a “low-range product.”
#
# 2) If the item’s price is above $5 but lower than or equal to $ 15, it will be labeled a “mid-range product.
#
# 3) If the item’s price is above $15, it will be labeled a “high-range product.”

# %%
# create a subset of just using the first million rows

df = df_ords_prods_merged [:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# ## Dataframe function to find the criteria
#
# def price_label(row):
#
#   if row['prices'] <= 5:
#
#     return 'Low-range product'
#
#   elif (row['prices'] > 5) and (row['prices'] <= 15):
#
#     return 'Mid-range product'
#
#   elif row['prices'] > 15:
#
#     return 'High range'
#
#   else: return 'Not enough data'

# %% [markdown]
# ## notes on the function above
#
# 1) always start with def to define what this new dataframe will look like
#
# 2) the (row) is meant so that the function can look at each row
#
# 3) finish with a colon to see what start the body
#
# 4) the if row['prices'] <= 5: return 'Low-range product' says that if the value of the prices column is less than 5, return a string that says "low-range product'. The : represents the THEN statement
#
# 5) make sure you have indentations. *CRUCIAL*
#
# 6) The "elif" stands for "else if"
#
# 7) Looking at the first two statements in a sentence:
#
# "If the value in the “prices” column within the given row is less than or equal to 5, then return the string “Low-range product.”
#
# Or else, if the value in the “prices” column within the given row is greater than 5 and less than or equal to 15, then return the string “Mid-range product.”
#
# 8) The else functions acts as a "bucket" to catch all of the remaining values
#
# Overall statement:
#
# If the value within the “prices” column within the given row is less than or equal to 5, then return the string “Low-range product.”
#
# Or else, if the value within the “prices” column within the given row is greater than 5 and less than or equal to 15, then return the string “Mid-range product.”
#
# Or else, if the value of the “prices” column within the given row is greater than 15, then return the string “High-range product.”
#
# Or else, return the string “Not enough data.”

# %% [markdown]
# ## Applying the function

# %%
# define the function
def price_label(row):

  if row['prices'] <= 5:
    
    return 'Low-range product'
  
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    
    return 'Mid-range product'
  
  elif row['prices'] > 15:
    
    return 'High range'
  
  else: return 'Not enough data'

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Akira\AppData\Local\Temp\ipykernel_16304\902492192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %% [markdown]
# the function above is telling the dataframe to create a new column 'price_range' and to apply the price_label function to each row 'axis = 1'

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range product    756450
# Low-range product    243550
# Name: count, dtype: int64

# %% [markdown]
#  There is no high-range product, meaning none of the million rows we checked have a price over $15

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# # If-Statements with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Akira\AppData\Local\Temp\ipykernel_16304\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# C:\Users\Akira\AppData\Local\Temp\ipykernel_16304\1169838859.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'High-range product' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %% [markdown]
# ## Notes on the functions above
#
# 1) the loc function is used to locate a specific column
#
# 2) the first section uses the loc and brackets to define we are looking at the prices column in the dataframe
#     2a) then using the <>= operators to compare the values
#
# 3)  The THEN statement is applied after the comma
#
# 4) the 'price_range_loc' means the new column
#
# Statement example:
#
# if = df.loc[df['prices'] > 15,
#
# then = 'price_range_loc'] = 'High-range product'
#
#
# if = df.loc[(df['prices'] <= 15) & (df['prices'] > 5),
#
# then = 'price_range_loc'] = 'Mid-range product'
#
# * make sure to separate two conditions with parenthesis and &

# %% [markdown]
# ## Running the same functions but replacing df with ords_prods_merged (entire dataframe)

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Akira\AppData\Local\Temp\ipykernel_16304\3564270281.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'High-range product' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_ords_prods_merged.loc[df_ords_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merged.loc[(df_ords_prods_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merged.loc[df_ords_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# NaN                   21104410
# Low-range product     10126321
# Mid-range product       756450
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# #### Using loc prevents a memory error by only looking at the prices column

# %% [markdown]
# # If-Statements with For-Loops

# %% [markdown]
# For-loops, as their name implies, are loops for running the same block of code multiple times. They’re used to perform the same function on multiple elements, for instance, by running through an entire dataframe and performing a function on each row within that dataframe.

# %%
# Example of for-loops capabilities

print ("My age is 31")
# Out:
# My age is 31

# %%
print ("My age is 32")
# Out:
# My age is 32

# %%
print ("My age is 33")
# Out:
# My age is 33

# %%
# for loop statements

for x in range(30, 45):
    print ("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %% [markdown]
# Here, the loop cycles for every value (x) within the range of 30 and 45. Each time it cycles, it executes the code inside the loop, which, in this case, prints “My age is” followed by the current value of x. The first loop starts at 30 since that’s the minimum value, so the value of x is 30, and the output is “My age is 30.” Once the code has been executed, the loop repeats for the next value in the range, 31, so the value of x is 31, and the output is “My age is 31.” Repeat, repeat, repeat, until the maximum value of 45 is reached and you have a result for every value within the range.

# %% [markdown]
# ## We are going to use the in-loop function to summarize how busy each day of the week is

# %%
df_ords_prods_merged.rename(columns={'order_dow' : 'orders_day_of_week'},inplace = True)

# %%
df_ords_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %% [markdown]
# ##### In your project brief, you can see that the value 0 means Saturday. This value has the highest frequency, meaning Saturday is the busiest day. Meanwhile, the 4 value has the lowest frequency. A value of 4, here, refers to Wednesday, meaning Wednesday is the slowest day for Instacart app orders.

# %% [markdown]
# You want to use this information to create a new column, “busiest day,” that will contain one of three different values: “Busiest day,” “Least busy,” and “Regularly busy.” This can be done using a for-loop. The loop will run through every row in the “orders_day_of_the_week” column, compare its value with what you know are the busiest and slowest days, and assign it the corresponding string value.
#
# The code would look like this:

# %%
result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %% [markdown]
# #### Notes on the function above
#
# 1) The result is creating an empty list to put values in
#
# 2) the reason of doing this method is to reduce the tiem to run the function
#
# 3) this function will run through each value of the orders_day_of_week and return a resonse
#
# 4) the elif again is the or,else function
#
# 5) the 'value' represents the "X" or placeholder value we are looking within the specified column

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %% [markdown]
# ## the list here is very long, and needs to be added to the dataframe

# %%
df_ords_prods_merged['busiest_day'] = result

# %%
df_ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0               11.114836         196                  1          0   both
# 1               15.000000         196                  1          1   both
# 2               21.000000         196                  1          1   both
# 3               29.000000         196                  1          1   both
# 4               28.000000         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %% [markdown]
# # 4.7 Assignment

# %% [markdown]
# ### Objective 1: create new busiest days column with now top two and bottom two days labeled

# %%
# Create new result in-loop function with updated changes
new_result = []

for value in df_ords_prods_merged["orders_day_of_week"]:
  if value == 0:
    new_result.append("Busiest day")
  elif value == 1:
    new_result.append("Busiest day")
  elif value == 4:
    new_result.append("Least busy")
  elif value == 3:
    new_result.append("Least busy")
  else:
    new_result.append("Regularly busy")

# %%
new_result
# Out:
# ['Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
# ...

# %%
#Insert new_results in overall dataframe
df_ords_prods_merged['busiest_days'] = new_result

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0               11.114836         196                  1          0   both
# 1               15.000000         196                  1          1   both
# 2               21.000000         196                  1          1   both
# 3               29.000000         196                  1          1   both
# 4               28.000000         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
# Checking for value counts

df_ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest day       11864412
# Least busy         7624336
# Name: count, dtype: int64

# %% [markdown]
# The most noticeable difference between the initial busiest_day column is that now regularly busy is not taking the overall majority of the days, but it still stands that more than half of the orders occurs on regularly busy days. With the inclusion of an additional day for busiest and least busy, the number of orders on those days have nearly doubled, which makes sense overall.

# %% [markdown]
# #### Objective 2: identify busiest hours of the day

# %%
df_ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# As a data analyst, I will be taking the lead on categorizing the top 8 hours as most, then next 8 as regular, and the bottom 8 will be labeled fewest orders

# %%
new_hour = []

for value in df_ords_prods_merged["order_hour_of_day"]:
  if value in [10, 11, 14, 15, 13, 12, 16, 9]:
    new_hour.append("Most orders")
  elif value in [17, 8, 18, 19, 20, 7, 21, 22]:
    new_hour.append("Average orders")
  else:
    new_hour.append("Fewest orders")

# %%
new_hour
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
#Insert new_hour in overall dataframe
df_ords_prods_merged['busiest_period_of_day'] = new_hour

# %%
# Checking value counts

df_ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# There seems to be no missing values in this set. Based on the frequency I can see that the top 8 hours for orders is the vast majority, which can be a great insight into adding additional features to improve Instacart.

# %% [markdown]
# ## Cleaning the Data and Export into pkl format

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0               11.114836         196                  1          0   both
# 1               15.000000         196                  1          1   both
# 2               21.000000         196                  1          1   both
# 3               29.000000         196                  1          1   both
# 4               28.000000         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
df_ords_prods_merged.shape
# Out:
# (32404859, 18)

# %%
df_ords_prods_merged.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_flags.pkl'))
